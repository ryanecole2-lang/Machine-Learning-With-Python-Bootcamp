# %% [markdown]
# <a href="https://colab.research.google.com/github/ryanecole2-lang/Machine-Learning-With-Python-Bootcamp/blob/main/Orientation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# A=2
# B=3
# C=A+B

# %%
A=2
B=3
C=A+B
print (C)
# Out:
# 5

# %% [markdown]
# Example of a String

# %%
Greeting= "What up doctor"
print (Greeting)
# Out:
# What up doctor
