# %% [markdown]
# <a href="https://colab.research.google.com/github/ryanecole2-lang/Machine-Learning-With-Python-Bootcamp/blob/main/Weekend_assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Problem #1

# %%
Liberia = 1847
print (Liberia)
print ("Liberia")
# Out:
# 1847
# Liberia

# %% [markdown]
# Problem 2

# %%
Country ="Liberia"
print(Country)
print("{Country} became independent in 1847")
# Out:
# Liberia
# {Country} became independent in 1847

# %% [markdown]
# Problem 3

# %%
print('The year is "1847"')
# Out:
# The year is "1847"

# %% [markdown]
# Problem 4

# %%
market_name = "Gobachop"
print("Market name:", market_name)
# Out:
# Market name: Gobachop

# %% [markdown]
# Problem #5

# %%
current_price = 2550.75
quantity=10
total_cost = current_price * quantity
print("Total cost for 10 bags:", total_cost)
print("Current_price",current_price)
print("quantity",quantity)
print(total_cost)
# Out:
# Total cost for 10 bags: 25507.5
# Current_price 2550.75
# quantity 10
# 25507.5

# %% [markdown]
# Problem 6

# %%
has_scarcity=False
is_rainy=True
print("Scacity today:", has_scarcity)
print("Rainy today:", is_rainy)
# Out:
# Scacity today: False
# Rainy today: True

# %% [markdown]
# Problem 7

# %%
total_revenue=800*25
print("Total revenue:", total_revenue)
# Out:
# Total revenue: 20000

# %% [markdown]
# Problrm 8

# %%
tomorrow_price=3200+150
print("tomorrow_price:", tomorrow_price)
# Out:
# tomorrow_price: 3350

# %% [markdown]
# Problem 9

# %%
cost_per_trader=1800/3
print("cost_per_trader:", cost_per_trader)
# Out:
# cost_per_trader: 600.0

# %% [markdown]
# Problem 10

# %%
discount_amount = 2500*0.10
print("discount_amount:", discount_amount)
# Out:
# discount_amount: 250.0

# %% [markdown]
# Problem 11

# %%
item="cassava"
price=800
print("item:", item)
print("price:", price)
# Out:
# item: cassava
# price: 800

# %% [markdown]
# Problem 12

# %%
product="pepper"
cost=150.50
print("One bag of",'pepper',"150.5",cost)
# Out:
# One bag of pepper 150.5 150.5
