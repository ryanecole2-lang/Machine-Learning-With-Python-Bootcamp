# %% [markdown]
# <a href="https://colab.research.google.com/github/ryanecole2-lang/Machine-Learning-With-Python-Bootcamp/blob/main/Class_Work.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('it's mine')
# Out:
#   File "/tmp/ipykernel_10174/372848286.py", line 1
#     print('it's mine)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print('it\'s mine')
# Out:
# it's mine

# %%
print("it's mine")
# Out:
# it's mine

# %% [markdown]
# Import Pandas as pd

# %%
import pandas as pd
gobachop_data = pd.DataFrame({
    "Vendor": ["Ma Musu", "Sia", "Flomo"],
     "Sales": [4000, 9500, 1500]
                              })
print("DataFrame Shape:", gobachop_data.shape)
print(gobachop_data.head())
print(gobachop_data.describe())
# Out:
# DataFrame Shape: (3, 2)
#     Vendor  Sales
# 0  Ma Musu   4000
# 1      Sia   9500
# 2    Flomo   1500
#              Sales
# count     3.000000
# mean   5000.000000
# std    4092.676386
# min    1500.000000
# 25%    2750.000000
# 50%    4000.000000
# 75%    6750.000000
# max    9500.000000
