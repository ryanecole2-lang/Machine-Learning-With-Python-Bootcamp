# %% [markdown]
# <a href="https://colab.research.google.com/github/ryanecole2-lang/Machine-Learning-With-Python-Bootcamp/blob/main/Python_Refresher.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Variable

# %%
# Create a labeled storage basket and put a number inside
tomato_price = 150
pepper_price = 80


# pull the value out of the baskets
print(tomato_price)
print(pepper_price)
# Out:
# 150
# 80

# %% [markdown]
# Change tomatoe price

# %%
tomato_price=100
print(tomato_price)
# Out:
# 100

# %% [markdown]
# Change the pepper price

# %%
pepper_price=150
print(pepper_price)
# Out:
# 150

# %% [markdown]
# VARIABLES (ML Anchor)

# %%
# --- THE CLUES (Features grouped as x) ---
rainfall_mm = 45.2     # Clue 1
bags_available = 100   # Clue 2

# --- THE TARGET (Target labeled as y) ---
predicted_price = 3200  # What our AI calculates
print("inputs (x):", rainfall_mm, "mm rain,", bags_available, "bags.")
print("output (y):", predicted_price, "LRD.")
# Out:
# inputs (x): 45.2 mm rain, 100 bags.
# output (y): 3200 LRD.

# %% [markdown]
# Undrstanding Print

# %%
Liberia=1847
print("Liberia")
print(1847)
# Out:
# Liberia
# 1847

# %% [markdown]
# DATA TYPES

# %%
quantity = 50
price = 150.50
item_name = "tomatoes"
stall_is_open =True

print(type(quantity))  #
print(type(price))     #
print(type(item_name)) #
print(type(stall_is_open)) #
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
