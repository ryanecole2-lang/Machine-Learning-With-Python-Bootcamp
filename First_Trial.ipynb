# %% [markdown]
# <a href="https://colab.research.google.com/github/ryanecole2-lang/Machine-Learning-With-Python-Bootcamp/blob/main/First_Trial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
R=15
S=20
V=R*S
print (V)
# Out:
# 300

# %% [markdown]
# Self Practice at its best

# %%
Greeting= "I bless God for his grace upon me and you?"
print (Greeting)
# Out:
# I bless God for his grace upon me and you?
